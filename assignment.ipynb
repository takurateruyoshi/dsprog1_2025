# %% [markdown]
# #  最終課題
#
# 課題のGithubリポジトリURLを提出してください＊Githubリポジトリは必ずpublicとしてください
#
# 武蔵野大学Webサイトのトップページにアクセス
#
# 同一ドメインの全てのリンク（コメントアウトされていないもの）を辿り，全ページのURLと<title>を辞書型変数に格納する
#
# key：URL
#
# value：<title></title>で挟まれた文字列
#
# 辞書型変数を print() で表示する

# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
# URL クラス
class URL:
    def __init__(self, url, path = '', domain = 'musashino-u.ac.jp'):
        self.url = url
        self.path = path
        self.domain = domain

        self.Protocol = self.url.split(':')[0]
        if self.Protocol != 'http' and self.Protocol != 'https':
            raise ValueError("Unsupported protocol")
        split_url = self.url.split('/')

        if len(split_url) < 3:
            raise ValueError("Invalid URL format")    
        self.FQDN = self.url.split('/')[2]

        if len(split_url) < 4:
             self.Path = ''
        else:
            self.Path = '/'.join(self.url.split('/')[3:])


    # getProrocol https or http
    def get_Protocol(self):
        return self.Protocol
    
    # getFQDN
    def get_FQDN(self):
        return self.FQDN

    # getPath
    def get_Path(self):
        return self.Path
    
    # getAbsURL
    def get_abs_URL(self):
        #空の場合自身のURLを返す
        if not self.path:
            return self.url
        #絶対パスに変換
        protocol = self.path.split(':')[0]
        if protocol == 'http' or protocol == 'https':
            return self.path
        elif self.path[0] == '/':
            return f"{self.Protocol}://{self.FQDN}{self.path}"
        else:
            return f"{self.url}/{self.path}"
        
    # checkDomain  
    def check_domain(self):
        return self.domain in self.FQDN

# %%
# URLクラス動作確認
url = URL("http://もオン/index.html", "/example/path.html")
print(f"プロトコル: {url.get_Protocol()}")
print(f"FQDN: {url.get_FQDN()}")
print(f"パス: {url.get_Path()}")
print(f"URL: {url.get_abs_URL()}")
print(f"ドメインチェック: {url.check_domain()}")
# Out:
# プロトコル: http
# FQDN: もオン
# パス: index.html
# URL: http://もオン/example/path.html
# ドメインチェック: False

# %%
# PAGE クラス
class PAGE:
    def __init__(self, url, target_filetype = 'text/html'):
        self.url = url
        self.target_filetype = target_filetype
        self.valid = False
        self.links = []

        time.sleep(0.3)
        try:
            res = requests.get(self.url)
        except requests.exceptions.RequestException as e:
            self.pagestate = f"リクエスト失敗: {e}"
        res.encoding = res.apparent_encoding

        status_code = res.status_code
        headers = res.headers.get('Content-Type', '拡張子が見つかりませんでした。')

        if status_code != 200:
            self.pagestate = f"[{status_code}エラー] :"
        elif 'text/html' not in headers:
            self.pagestate =  f"[非HTML] : {headers}"        
        else:
            self.pagestate = "正常"
            self.valid = True
            self.soup = BeautifulSoup(res.text, 'html.parser')
            self.title = self.soup.find('title').string if self.soup.find('title') else 'タイトルなし'
            new_hrefs = self.soup.find_all(attrs={'href':True})
            for new_href in new_hrefs:
                new_url = new_href.get('href')
                target_url = URL(self.url, new_url)
                self.links.append(target_url.get_abs_URL())
                         
    #isValid
    def __private_is_Valid(self):
        if self.valid == False:
            raise ValueError("Invalid page")

    def is_Valid(self):
        return self.valid
    # requestStatus
    def check_Page(self):
        return self.pagestate
    
    # getPage
    def get_Soup(self):
        self.__private_is_Valid()
        return self.soup
    
    # getPageTitle
    def get_Title(self):
        self.__private_is_Valid()
        return self.title
    
    # getPageLinks
    def get_Links(self):
        self.__private_is_Valid()
        return self.links

# %%
# PAGEクラス動作確認
soup = PAGE("https://www.musashino-u.ac.jp/")
print(f"リクエスト状況: {soup.check_Page()}")
print(f"ページタイトル: {soup.get_Title()}")
print(f"リンク一覧: {soup.get_Links()}")
# Out:
# リクエスト状況: 正常
# ページタイトル: 武蔵野大学
# リンク一覧: ['https://www.musashino-u.ac.jp/', 'https://www.musashino-u.ac.jp/', 'https://www.musashino-u.ac.jp/en/', 'https://www.musashino-u.ac.jp/assets/img/common/favicon.ico', 'https://www.musashino-u.ac.jp/assets/img/common/apple-touch-icon_180x180.png', 'https://www.musashino-u.ac.jp/assets/img/common/android-chrome_256x256.png', 'https://fonts.googleapis.com', 'https://fonts.gstatic.com', 'https://fonts.googleapis.com/css2?family=BIZ+UDPGothic:wght@400;700&family=Cormorant+Garamond:wght@700&family=Hind:wght@700&display=swap', 'https://www.musashino-u.ac.jp/assets/css/destyle.min.css', 'https://www.musashino-u.ac.jp/assets/css/swiper-bundle.min.css', 'https://www.musashino-u.ac.jp/assets/css/scroll-hint.css', 'https://www.musashino-u.ac.jp/assets/ss/ss_search.css', 'https://www.musashino-u.ac.jp/assets/ss/ss_suggest.css', 'https://www.musashino-u.ac.jp/assets/css/main.css?20251110091222', 'https://www.musashino-u.ac.jp/assets/css/modules.css?20251110091222', 'https://www.musashino-u.ac.jp//#main', 'https://www.musashino-u.ac.jp/', 'https://ef.musashino-u.ac.jp/donation/', 'https://www.musashino-u.ac.jp/access.html', 'https://www.musashino-u.ac.jp/admission/request.html', 'https://www.musashino-u.ac.jp/contact.html', 'https://www.musashino-u.ac.jp/', 'https://musashino-u.j-server.com/LUCAIMSSNU/ns/w4/jaen/', 'https://musashino-u.j-server.com/LUCAIMSSNU/ns/w4/jako/', 'https://musashino-u.j-server.com/LUCAIMSSNU/ns/w4/jazh/', 'https://www.musashino-u.ac.jp/prospective-students.html', 'https://www.musashino-u.ac.jp/students.html', 'https://www.musashino-u.ac.jp/alumni.html', 'https://www.musashino-u.ac.jp/parents.html', 'https://www.musashino-u.ac.jp/business.html', 'https://www.musashino-u.ac.jp/guide/', 'https://www.musashino-u.ac.jp/guide/', 'https://www.musashino-u.ac.jp/guide/profile/', 'https://www.musashino-u.ac.jp/guide/activities/', 'https://www.musashino-u.ac.jp/guide/campus/', 'https://www.musashino-u.ac.jp/guide/facility/', 'https://www.musashino-u.ac.jp/guide/information/', 'https://www.musashino-u.ac.jp/guide/profile/media/', 'https://www.musashino-u.ac.jp/admission/', 'https://www.musashino-u.ac.jp/admission/', 'https://www.musashino-u.ac.jp/admission/faculty/', 'https://www.musashino-u.ac.jp/admission/international_students/', 'https://www.musashino-u.ac.jp/admission/graduate_school/', 'https://www.musashino-u.ac.jp/admission/advanced_course/', 'https://www.musashino-u.ac.jp/admission/short_term_course/', 'https://www.musashino-u.ac.jp/admission/event/', 'https://www.musashino-u.ac.jp/admission/faq/', 'https://www.musashino-u.ac.jp/admission/download/', 'https://www.musashino-u.ac.jp/admission/request.html', 'https://www.musashino-u.ac.jp/basic/', 'https://www.musashino-u.ac.jp/basic/', 'https://www.musashino-u.ac.jp/basic/purpose.html', 'https://www.musashino-u.ac.jp/basic/policies/', 'https://www.musashino-u.ac.jp/basic/learning_cycle.html', 'https://www.musashino-u.ac.jp/basic/initial/', 'https://www.musashino-u.ac.jp/basic/endowment_course.html', 'https://www.musashino-u.ac.jp/basic/consortium.html', 'https://www.musashino-u.ac.jp/basic/generation_ai/index.html', 'https://www.musashino-u.ac.jp/academics/', 'https://www.musashino-u.ac.jp/academics/', 'https://www.musashino-u.ac.jp/academics/faculty/', 'https://www.musashino-u.ac.jp/academics/graduate_school/', 'https://dl.musashino-u.ac.jp/', 'https://www.musashino-u.ac.jp/academics/advanced_course/', 'https://www.musashino-u.ac.jp/academics/special_course/', 'https://www.musashino-u.ac.jp/academics/Lifelong_learning/', 'https://www.musashino-u.ac.jp/academics/teachers_license/', 'https://www.musashino-u.ac.jp/research/', 'https://www.musashino-u.ac.jp/research/', 'https://www.musashino-u.ac.jp/research/laboratory/', 'https://www.musashino-u.ac.jp/research/kakenhi/', 'https://www.musashino-u.ac.jp/research/cooperation/', 'https://www.musashino-u.ac.jp/research/ethics/', 'https://www-cv01.ufinity.jp/musashino/', 'https://www.musashino-u.ac.jp/research/interview ...

# %%
#　メインコード
def scraping(start_url):
    to_scrap = [start_url]
    scraped = []
    page_dict = {}
    while to_scrap:

        #ページにアクセス
        current_url = to_scrap.pop(0)
        page_obj = PAGE(current_url)
        print(f" {page_obj.check_Page()}({len(scraped)}/{len(scraped) + len(to_scrap)}): {current_url}")

        # エラーページはスキップ
        if page_obj.is_Valid() == False:
            scraped.append(current_url)
            continue

        # 正常ページはリンクを取得
        else:
            title = page_obj.get_Title()
            urls = page_obj.get_Links()
            for url in urls:
                url_obj = URL(current_url, url)
                abs_url = url_obj.get_abs_URL()
                abs_url_obj = URL(abs_url)
                if (abs_url_obj.check_domain() and 
                    abs_url not in scraped and
                    abs_url not in to_scrap):
                    to_scrap.append(abs_url)
            scraped.append(current_url)
            page_dict[current_url] = title
        
    return page_dict

# %%
START_URL = "https://www.musashino-u.ac.jp/news/"

print(f"開始します: {START_URL}")

page_data = scraping(START_URL)

print(f"終了しました:{len(page_data)} ページを取得")

print("--- 辞書型変数の内容 ---")
for pages_data in page_data.items():
    print(pages_data)
# Out:
# 開始します: https://www.musashino-u.ac.jp/news/
#  正常(0/0): https://www.musashino-u.ac.jp/news/
#  正常(1/124): https://www.musashino-u.ac.jp/news/index.php
#  [500エラー] :(2/132): https://www.musashino-u.ac.jp/en/news/
#  [非HTML] : image/vnd.microsoft.icon(3/132): https://www.musashino-u.ac.jp/assets/img/common/favicon.ico
#  [非HTML] : image/png(4/132): https://www.musashino-u.ac.jp/assets/img/common/apple-touch-icon_180x180.png
#  [非HTML] : image/png(5/132): https://www.musashino-u.ac.jp/assets/img/common/android-chrome_256x256.png
#  [非HTML] : text/css(6/132): https://www.musashino-u.ac.jp/assets/css/destyle.min.css
#  [非HTML] : text/css(7/132): https://www.musashino-u.ac.jp/assets/css/swiper-bundle.min.css
#  [非HTML] : text/css(8/132): https://www.musashino-u.ac.jp/assets/css/scroll-hint.css
#  [非HTML] : text/css(9/132): https://www.musashino-u.ac.jp/assets/ss/ss_search.css
#  [非HTML] : text/css(10/132): https://www.musashino-u.ac.jp/assets/ss/ss_suggest.css
#  [非HTML] : text/css(11/132): https://www.musashino-u.ac.jp/assets/css/main.css?20251110090137
#  [非HTML] : text/css(12/132): https://www.musashino-u.ac.jp/assets/css/modules.css?20251110090137
#  正常(13/132): https://www.musashino-u.ac.jp/news//#main
#  正常(14/139): https://www.musashino-u.ac.jp/
#  正常(15/171): https://ef.musashino-u.ac.jp/donation/
#  正常(16/210): https://www.musashino-u.ac.jp/access.html
#  正常(17/223): https://www.musashino-u.ac.jp/admission/request.html
#  正常(18/270): https://www.musashino-u.ac.jp/contact.html
#  正常(19/302): https://www.musashino-u.ac.jp/prospective-students.html
#  正常(20/327): https://www.musashino-u.ac.jp/students.html
#  正常(21/338): https://www.musashino-u.ac.jp/alumni.html
#  正常(22/343): https://www.musashino-u.ac.jp/parents.html
#  正常(23/351): https://www.musashino-u.ac.jp/business.html
#  正常(24/358): https://www.musashino-u.ac.jp/guide/
#  正常(25/390): https://www.musashino-u.ac.jp/guide/profile/
#  正常(26/420): https://www.musashino-u.ac.jp/guide/activities/
#  正常(27/429): https://www.musashino-u.ac.jp/guide/campus/
#  正常(28/435): https://www.musashino-u.ac.jp/guide/facility/
#  正常(29/473): https://www.musashino-u.ac.jp/guide/information/
#  正常(30/554): https://www.musashino-u.ac.jp/guide/profile/media/
#  正常(31/558): https://www.musashino-u.ac.jp/admission/
#  正常(32/572): https://www.musashino-u.ac.jp/admission/faculty/
#  正常(33/588): https://www.musashino-u.ac.jp/admission/international_students/
#  正常(34/596): https://www.musashino-u.ac.jp/admission/graduate_school/
#  正常(35/605): https://www.musashino-u.ac.jp/admission/advanced_course/
#  正常(36/610): https://www.musashino-u.ac.jp/admission/short_term_course/
#  正常(37/614): https://www.musashino-u.ac.jp/admission/event/
#  正常(38/618): https://www.musashino-u.ac.jp/admission/faq/
#  正常(39/630): https://www.musashino-u.ac.jp/admission/download/
#  正常(40/635): https://www.musashino-u.ac.jp/basic/
#  正常(41/649): https://www.musashino-u.ac.jp/basic/purpose.html
#  正常(42/728): https://www.musashino-u.ac.jp/basic/policies/
#  正常(43/734): https://www.musashino-u.ac.jp/basic/learning_cycle.html
#  正常(44/737): https://www.musashino-u.ac.jp/basic/initial/
#  正常(45/750): https://www.musashino-u.ac.jp/basic/endowment_course.html
#  正常(46/753): https://www.musashino-u.ac.jp/basic/consortium.html
#  正常(47/757): https://www.musashino-u.ac.jp/basic/generation_ai/index.html
#  正常(48/764): https://www.musashino-u.ac.jp/academics/
#  正常(49/795): https://www.musashino-u.ac.jp/academics/faculty/
#  正常(50/802): https://www.musashino-u.ac.jp/academics/graduate_school/
#  正常(51/833): https://dl.musashino-u.ac.jp/
#  正常(52/919): https://www.musashino-u.ac.jp/academics/advanced_course/
#  正常(53/942): https://www.musashino-u.ac.jp/academics/special_course/
#  正常(54/948): https://www.musashino-u.ac.jp/academics/Lifelong_learning/
#  正常(55/955): https://www.musashino-u.ac.jp/academics/teachers_license/
#  正常(56/960): https://www.musashino-u.ac.jp/research/
#  正常(57/972): https://www.musashino-u.ac.jp/research/laboratory/
#  正常(58/982): https://www.musashino-u.ac.jp/research/kakenhi/
#  正常(59/987): https://www.musashino-u.ac.jp/research/cooperation/
#  正常(60/996): https://www.musashino-u.ac.jp/research/ethics/
#  正常(61/1002): https://www.musashino-u.ac.jp/research/interview/
#  正常(62/1074): https://www.musashino-u.ac.jp/research/alignment/collaborativeresearch.html
#  正常(63/1078): https://www.musashino-u.ac.jp/international/
#  正常(64/1103): https://www.musashino-u.ac.jp/international/international-center/
#  正常(65/1112): https://www.musashino-u.ac.jp/international/study-abroad/
#  正常(66/1125): https://www.musashino-u.ac.jp/international/international-students/
#  正常(67/1144): https://www.musashino-u.ac.jp/international/events/
#  正常(68/1150): https://www.musashino-u.ac.jp/international/research_results/
#  正常(69/1155): https://www.musashino-u.ac.jp/international/gc_portal/
#  正常(70/1161): https://www.musashino-u.ac.jp/student-life/
#  正常(71/1196): https://www.musashino-u.ac.jp/student-life/learning/
#  正常(72/1208): https://www.musashino-u.ac.jp/student-life/life/
#  正常(73/1215): https://www.musashino-u.ac.jp/student-life/application/
#  正常(74/1220): https://www.musashino-u.ac.jp/student-life/fees/
#  正常(75/1224): https://www.musashino-u.ac.jp/student-life/campus_life/
#  正常(76/1228): https://www.musashino-u.ac.jp/student-life/career/
#  正常(77/1241): https://www.musashino-u.ac.jp/student-life/tool/
#  正常(78/1247): https://www.musashino-u.ac.jp/news/
#  正常(79/1247): https://www.musashino-u.ac.jp/news/2025/?type=重要なお知らせ
#  正常(80/1265): https://www.musashino-u.ac.jp/news/press/
#  正常(81/1296): https://www.musashino-u.ac.jp/news/2025/?category=大学案内
#  正常(82/1309): https://www.musashino-u.ac.jp/news/2025/?category=入試情報
#  正常(83/1316): https://www.musashino-u.ac.jp/news/2025/?category=教育の特長
#  正常(84/1325): https://www.musashino-u.ac.jp/news/2025/?category=学部・大学院
#  正常(85/1334): https://www.musashino-u.ac.jp/news/2025/?category=研究
#  正常(86/1350): https://www.musashino-u.ac.jp/news/2025/?category=国際交流・留学
#  正常(87/1363): https://www.musashino-u.ac.jp/news/2025/?category=学生生活・就職
#  正常(88/1370): https://www.musashino-u.ac.jp/news/2025/?category=法人
#  正常(89/1377): https://www.musashino-u.ac.jp/news/2025/?category=図書館
#  正常(90/1382): https://www.musashino-u.ac.jp/news/detail/20251107-7396.html
#  正常(91/1388): https://www.musashino-u.ac.jp/news/detail/20251107-7391.html
#  正常(92/1393): https://www.musashino-u.ac.jp/news/detail/20251105-7385.html
#  正常(93/1399): https://www.musashino-u.ac.jp/admission/download/faculty.html#mids
#  正常(94/1453): https://www.musashino-u.ac.jp/news/detail/20251104-7308.html
#  正常(95/1458): https://www.musashino-u.ac.jp/news/detail/20251030-7383.html
#  [非HTML] : application/pdf(96/1463): https://www.musashino-u.ac.jp/research/2025_MIGA%E3%82%B3%E3%83%A9%E3%83%A0_%28%E5%A4%A7%E6%9E%97%E5%85%88%E7%94%9F2025.10.27%29.pdf
#  正常(97/1463): https://www.musashino-u.ac.jp/news/detail/20251029-7375.html
#  正常(98/1468): https://www.musashino-u.ac.jp/news/detail/20251029-7380.html
#  正常(99/1475): https://www.musashino-u.ac.jp/admission/download/faculty.html#well-being
#  正常(100/1479): https://www.musashino-u.ac.jp/research/interview/69_kutsuzawa/index.html
#  正常(101/1489): https://www.musashino-u.ac.jp/news//./?page=1
#  正常(102/1496): https://www.musashino-u.ac.jp/news//./?page=2
#  正常(103/1503): https://www.musashino-u.ac.jp/news//./?page=3
#  正常(104/1510): https://www.musashino-u.ac.jp/news//./?page=4
#  正常(105/1523): https://www.musashino-u.ac.jp/news//./?page=5
#  正常(106/1531): https://www.musashino-u.ac.jp/news/2025/
#  正常(107/1540): https://www.musashino-u.ac.jp/news/2024/
#  正常(108/1564): https://www.musashino-u.ac.jp/news/2023/
#  正常(109/1583): https://www.musashino-u.ac.jp/news/2022/
#  正常(110/1602): https://www.musashino-u.ac.jp/news/2021/
#  正常(111/1614): https://www.musashino-u.ac.jp/news/2020/
#  正常(112/1627): https://www.musashino-u.ac.jp/news/2019/
#  正常(113/1643): https://www.musashino-u.ac.jp/news/2018/
#  正常(114/1648): https://www.musashino-u.ac.jp/news/2017/
#  正常(115/1656): https://www.musashino-u.ac.jp/news/2016/
#  正常(116/1663): https://www.musashino-u.ac.jp/news/2015/
#  正常(117/1668): https://www.musashino-u.ac.jp/ariake/
#  正常(118/1671): https://www.musashino-u.ac.jp/musashino/
#  正常(119/1675): https://www.musashino-u.ac.jp/academics/basic/
#  正常(120/1681): https://www.musashino-u.ac.jp/news//#top
#  正常(121/1688): https://www.musashino-u.ac.jp/guide/activities/privacypolicy.html
#  正常(122/1692): https://www.musashino-u.ac.jp/accesibility-and-copyright.html
#  正常(123/1697): https://ef.musashino-u.ac.jp/recruit/
#  正常(124/1712): https://ef.musashino-u.ac.jp/
#  正常(125/1723): https://www.musashino-u.ac.jp/news/index.php
#  正常(126/1723): https://www.musashino-u.ac.jp/news/index.php/#main
#  正常(127/1730): https://www.musashino-u.ac.jp/news/index.php/./?page=1
#  正常(128/1737): https://www.musashino-u.ac.jp/news/index.php/./?page=2
#  正常(129/1744): https://www.musashino-u.ac.jp/news/index.php/./?page=3
#  正常(130/1751): https://www.musashino-u.ac.jp/news/index.php/./?page=4
#  正常(131/1758): https://www.musashino-u.ac.jp/news/index.php/./?page=5
#  正常(132/1765): https://www.musashino-u.ac.jp/news/index.php/#top
#  正常(133/1772): https://www.musashino-u.ac.jp/news//#main/#main
#  正常(134/1779): https://www.musashino-u.ac.jp/news//#main/./?page=1
#  正常(135/1786): https://www.musashino-u.ac.jp/news//#main/./?page=2
#  正常(136/1793): https://www.musashino-u.ac.jp/news//#main/./?page=3
#  正常(137/1800): https://www.musashino-u.ac.jp/news//#main/./?page=4
#  正常(138/1807): https://www.musashino-u.ac.jp/news//#main/./?page=5
#  正常(139/1814): https://www.musashino-u.ac.jp/news//#main/#top
#  正常(140/1821): https://www.musashino-u.ac.jp/
#  [500エラー] :(141/1821): https://www.musashino-u.ac.jp/en/
#  [非HTML] : text/css(142/1821): https://www.musashino-u.ac.jp/assets/css/main.css?20251110091222
#  [非HTML] : text/css(143/1821): https://www.musashino-u.ac.jp/assets/css/modules.css?20251110091222
#  正常(144/1821): https://www.musashino-u.ac.jp//#main
#  正常(145/1823): https://www.musashino-u.ac.jp/news/detail/20250701-6913.html
#  正常(146/1830): https://www.musashino-u.ac.jp/guide/profile/message.html
#  正常(147/1833): https://www.musashino-u.ac.jp/admission/faculty/event/oc/
#  正常(148/1856): https://www.musashino-u.ac.jp/basic/buddhist_studies/
#  正常(149/1866): https://www.musashino-u.ac.jp/guide/facility/MUSIC_center/submajor_aiexpert.html
#  正常(150/1870): https://www.musashino-u.ac.jp/academics/faculty/well-being/well-being/
#  正常(151/1881): https://sdgs.musashino-u.ac.jp/
#  正常(152/1910): https://www.musashino-u.ac.jp/enverse/
#  正常(153/1917): https://www.musashino-u.ac.jp/admission/student_support_site/
#  正常(154/1931): https://www.musashino-u.ac.jp/guide/profile/infographic.html
#  正常(155/1934): https://www.musashino-u.ac.jp/guide/profile/history.html
#  正常(156/1941): https://www.musashino-u.ac.jp/international/study-abroad/index.html
#  正常(157/1944): https://www.musashino-u.ac.jp/basic/initial/fs/index.html
#  正常(158/1954): https://www.musashino-u.ac.jp/basic/#numbers
#  正常(159/1959): https://www.musashino-u.ac.jp/happiness_creators/
#  正常(160/1989): https://www.musashino-u.ac.jp/happiness_creators/no030.html
#  正常(161/1993): https://www.musashino-u.ac.jp/happiness_creators/no029.html
#  正常(162/1996): https://www.musashino-u.ac.jp/happiness_creators/no028.html
#  正常(163/1999): https://www.musashino-u.ac.jp/happiness_creators/no027.html
#  正常(164/2002): https://www.musashino-u.ac.jp/happiness_creators/no026.html
#  正常(165/2005): https://www.musashino-u.ac.jp/happiness_creators/no025.html
#  正常(166/2008): https://www.musashino-u.ac.jp/times/
#  正常(167/2023): https://www.musashino-u.ac.jp/research/laboratory/mathematical_engineering/seminar_symposium.html
#  正常(168/2133): https://www.musashino-u.ac.jp/event/detail/20251112-7302.html
#  正常(169/2144): https://www.musashino-u.ac.jp/research/laboratory/mathematical_engineering/seminar_symposium.html#section02
#  正常(170/2228): https://www.musashino-u.ac.jp/event/
#  正常(171/2252): https://www.musashino-u.ac.jp//#top
#  正常(172/2254): https://ef.musashino-u.ac.jp/donation/
#  [非HTML] : image/vnd.microsoft.icon(173/2254): https://ef.musashino-u.ac.jp/favicon.ico
#  [非HTML] : image/png(174/2254): https://ef.musashino-u.ac.jp/apple-touch-icon-180x180.png
#  [非HTML] : image/png(175/2254): https://ef.musashino-u.ac.jp/android-chrome-256x256.png
#  [非HTML] : text/css(176/2254): https://ef.musashino-u.ac.jp/assets/css/destyle.min.css
#  [非HTML] : text/css(177/2254): https://ef.musashino-u.ac.jp/assets/css/swiper-bundle.min.css
#  [非HTML] : text/css(178/2254): https://ef.musashino-u.ac.jp/assets/css/scroll-hint.css
#  [非HTML] : text/css(179/2254): https://ef.musashino-u.ac.jp/assets/css/main.css?20250418164324
#  [非HTML] : text/css(180/2254): https://ef.musashino-u.ac.jp/assets/css/modules.css?20250418164324
#  正常(181/2254): https://ef.musashino-u.ac.jp/donation//#main
#  正常(182/2256): https://ef.musashino-u.ac.jp/about/
#  正常(183/2273): https://ef.musashino-u.ac.jp/about/message/
#  正常(184/2278): https://ef.musashino-u.ac.jp/about/history/
#  正常(185/2283): https://ef.musashino-u.ac.jp/about/granddesign/
#  正常(186/2290): https://ef.musashino-u.ac.jp/about/vision/
#  正常(187/2297): https://ef.musashino-u.ac.jp/about/schools/
#  正常(188/2311): https://ef.musashino-u.ac.jp/about/pamphlet/
#  正常(189/2318): https://ef.musashino-u.ac.jp/about/journal/
#  正常(190/2324): https://ef.musashino-u.ac.jp/about/#basic
#  正常(191/2327): https://ef.musashino-u.ac.jp/about/#financial
#  正常(192/2330): https://ef.musashino-u.ac.jp/about/#facilities
#  正常(193/2333): https://ef.musashino-u.ac.jp/about/#audit
#  正常(194/2336): https://ef.musashino-u.ac.jp/about/#policies
#  正常(195/2339): https://ef.musashino-u.ac.jp/about/#application
#  正常(196/2342): https://ef.musashino-u.ac.jp/news/2025/?category=活動レポート
#  正常(197/2357): https://ef.musashino-u.ac.jp/news/
#  正常(198/2381): https://ef.musashino-u.ac.jp/info/
#  正常(199/2396): https://ef.musashino-u.ac.jp/donation/100th-anniversary/
#  正常(200/2401): https://ef.musashino-u.ac.jp/donation/dana/
#  正常(201/2404): https://ef.musashino-u.ac.jp/donation/application/
#  正常(202/2413): https://ef.musashino-u.ac.jp/donation/preferential/
#  正常(203/2418): https://ef.musashino-u.ac.jp/donation/property/
#  正常(204/2423): https://www.musashino-u.ac.jp
#  正常(205/2425): https://kg.musashino-u.ac.jp
#  正常(206/2472): https://ak.musashino-u.ac.jp
#  正常(207/2495): https://100th.musashino-u.ac.jp
#  正常(208/2531): https://ef.musashino-u.ac.jp/donation//#top
#  正常(209/2533): https://ef.musashino-u.ac.jp/sitemap/
#  正常(210/2537): https://ef.musashino-u.ac.jp/about/privacy-policy/index.html
#  正常(211/2543): https://www.musashino-u.ac.jp/access.html
#  [非HTML] : text/css(212/2543): https://www.musashino-u.ac.jp/assets/css/main.css?20251110091224
#  [非HTML] : text/css(213/2543): https://www.musashino-u.ac.jp/assets/css/modules.css?20251110091224
#  [404エラー] :(214/2543): https://www.musashino-u.ac.jp/access.html/#main
#  正常(215/2543): https://www.musashino-u.ac.jp/ariake/index.html
#  正常(216/2545): https://www.musashino-u.ac.jp/guide/campus/ariake_campus.html
#  正常(217/2548): https://www.musashino-u.ac.jp/admission/event/campus_tour.html
#  正常(218/2557): https://www.musashino-u.ac.jp/ariake/area_info.html
#  正常(219/2560): https://www.musashino-u.ac.jp/musashino/index.html
#  正常(220/2562): https://www.musashino-u.ac.jp/guide/campus/musashino_campus.html
#  正常(221/2565): https://www.musashino-u.ac.jp/musashino/area_info.html
#  正常(222/2568): https://www.musashino-u.ac.jp/satellite_mitaka.html
#  [404エラー] :(223/2571): https://www.musashino-u.ac.jp/access.html/#top
#  正常(224/2571): https://www.musashino-u.ac.jp/admission/request.html
#  [非HTML] : text/css(225/2571): https://www.musashino-u.ac.jp/assets/css/main.css?20251110091212
#  [非HTML] : text/css(226/2571): https://www.musashino-u.ac.jp/assets/css/modules.css?20251110091212
#  [404エラー] :(227/2571): https://www.musashino-u.ac.jp/admission/request.html/#main
#  [404エラー] :(228/2571): https://www.musashino-u.ac.jp/admission/request.html/#section01
#  正常(229/2571): https://dl.musashino-u.ac.jp/request/
#  正常(230/2580): https://www.musashino-u.ac.jp/admission/download/index.html
#  [非HTML] : application/pdf(231/2583): https://www.musashino-u.ac.jp/admission/pdf/a9cce3d20105a22ed9cbcf90fb49aac7_1.pdf
#  [非HTML] : application/pdf(232/2583): https://www.musashino-u.ac.jp/admission/pdf/%E4%BF%9D%E8%AD%B7%E8%80%85%E3%83%BB%E6%95%99%E5%93%A1%E5%90%91%E3%81%91%E3%83%AA%E3%83%BC%E3%83%95%E3%83%AC%E3%83%83%E3%83%88_1.pdf
#  [非HTML] : application/pdf(233/2583): https://www.musashino-u.ac.jp/admission/pdf/%E6%AD%A6%E8%94%B5%E9%87%8EINITIAL%E3%83%AA%E3%83%BC%E3%83%95%E3%83%AC%E3%83%83%E3%83%88.pdf
#  [非HTML] : application/pdf(234/2583): https://www.musashino-u.ac.jp/admission/pdf/%E3%83%87%E3%83%BC%E3%82%BF%E3%82%B5%E3%82%A4%E3%82%A8%E3%83%B3%E3%82%B9%E5%AD%A6%E7%A7%91%E3%83%81%E3%83%A9%E3%82%B7.pdf
#  [非HTML] : application/pdf(235/2583): https://www.musashino-u.ac.jp/admission/pdf/%E2%98%85GC%E5%AD%A6%E7%A7%91%E5%85%A8%E5%93%A1%E7%95%99%E5%AD%A6%E3%83%81%E3%83%A9%E3%82%B7.pdf
#  正常(236/2583): https://www.musashino-u.ac.jp/admission/download/faculty.html
#  正常(237/2587): https://www.musashino-u.ac.jp/admission/download/international_students.html
#  正常(238/2603): https://www.musashino-u.ac.jp/admission/download/graduate_school.html
#  正常(239/2632): https://www.musashino-u.ac.jp/admission/advanced_course/slht.html#id01
#  正常(240/2644): https://www.musashino-u.ac.jp/admission/faculty/schedule.html
#  正常(241/2665): https://www.musashino-u.ac.jp/admission/faculty/detail/
#  正常(242/2690): https://www.musashino-u.ac.jp/admission/faculty/detail/faculty.html
#  正常(243/2718): https://www.musashino-u.ac.jp/admission/faculty/point/
#  正常(244/2729): https://www.musashino-u.ac.jp/admission/faculty/net.html
#  正常(245/2732): https://www.musashino-u.ac.jp/admission/faculty/examinee.html
#  正常(246/2738): https://www.musashino-u.ac.jp/admission/faculty/announcement.html
#  正常(247/2741): https://www.musashino-u.ac.jp/admission/faculty/result.html
#  正常(248/2763): https://www.musashino-u.ac.jp/admission/faculty/pastpapers.html
#  正常(249/2817): https://www.musashino-u.ac.jp/admission/faculty/correct_answer.html
#  正常(250/2871): https://www.musashino-u.ac.jp/admission/faculty/hs_code.html
#  正常(251/2875): https://www.musashino-u.ac.jp/admission/faculty/policies.html
#  正常(252/2899): https://www.musashino-u.ac.jp/admission/faculty/event/weboc/
#  正常(253/2907): https://www.musashino-u.ac.jp/admission/international_students/global_studies.html
#  正常(254/2915): https://www.musashino-u.ac.jp/admission/international_students/other_studies.html
#  正常(255/2923): https://www.musashino-u.ac.jp/admission/international_students/result.html
#  正常(256/2929): https://www.musashino-u.ac.jp/admission/graduate_school/schedule01.html
#  正常(257/2940): https://www.musashino-u.ac.jp/admission/graduate_school/schedule02.html
#  正常(258/2946): https://www.musashino-u.ac.jp/admission/graduate_school/selection.html
#  正常(259/2951): https://www.musashino-u.ac.jp/admission/graduate_school/announcement.html
#  正常(260/2954): https://www.musashino-u.ac.jp/admission/graduate_school/result.html
#  正常(261/2960): https://www.musashino-u.ac.jp/admission/graduate_school/pastpapers.html
#  正常(262/3005): https://www.musashino-u.ac.jp/admission/graduate_school/net.html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 5
#       1 START_URL = "https://www.musashino-u.ac.jp/news/"
#       3 print(f"開始します: {START_URL}")
# ----> 5 page_data = scraping(START_URL)
#       7 print(f"終了しました:{len(page_data)} ページを取得")
#       9 print("--- 辞書型変数の内容 ---")
#
# Cell In[18], line 10, in scraping(start_url)
#       6 while to_scrap:
#       7
#       8     #調査済みURLはスキップ
#       9     current_url = to_scrap.pop(0)
# ---> 10     page_obj = PAGE(current_url)
#      11     print(f" {page_obj.check_Page()}({len(scraped)}/{len(scraped) + len(to_scrap)}): {current_url}")
#      13     if page_obj.is_Valid() == False:
#
# Cell In[16], line 9, in PAGE.__init__(self, url, target_filetype)
#       6 self.valid = False
#       7 self.links = []
# ----> 9 time.sleep(0.3)
#      10 try:
#      11     res = requests.get(self.url)
#
# KeyboardInterrupt:

# %% [markdown]
# # 　拡張したいコード
#
# エラーが発生したときにスクレイピングが途中から復旧できるような構造にしたい

# %%
import csv

# %%
# [TODO: DATAクラスの実装]
# DATA クラス
class DATA:
    def __init__(self, url, title, state = 'new'):
        self.url = url
        self.title = title
        self.state = state

        self.data.append({
            'url': self.url,
            'state': self.state,
            'title': self.title
        })
        


    # saveData　データを保存するURLリストが追加されるたびに保存
    def save_data(self):
        #csvに入れます
        with open('assignment.csv', 'w', newline='', encoding='utf-8') as f:
            writer = csv.writer(f)
            writer.writerows(self.data)
        
    # roadData　データを読み込む
    def load_data(self):
        #csvから読み込みます
        try:
            with open('assignment.csv', 'r', newline='', encoding='utf-8') as f:
                # 1. csv.readerオブジェクトを作成
                reader = csv.reader(f)
                
                # 2. readerをリストに変換して、全データを一括で読み込む
                # (readerはイテレータなので、forループで1行ずつ処理することも可能です)
                data_list = list(reader)

            # 読み込んだデータを表示して確認
            print(f"--- {f'assignment.csv'} から読み込んだデータ ---")
            for row in data_list:
                print(row)
                # print(f"読み込んだデータ全体: {data_list}") # こちらでもOK

        except FileNotFoundError:
            print(f"エラー: ファイル 'assignment.csv' が見つかりません。")
        except Exception as e:
            print(f"エラーが発生しました: {e}")
        

    # checkData　URLリストのデータと新しく追加したデータを照合
    def check_data(self):
# Out:
#   Cell In[252], line 51
#
#     ^
# SyntaxError: incomplete input
